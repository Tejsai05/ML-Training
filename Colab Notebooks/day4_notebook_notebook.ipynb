# %%
n = int(input("Enter a positive integer: "))
sum_even = 0

for i in range(1, n + 1):
    if i % 2 == 0:
        sum_even += i

print("Sum of all even numbers between 1 and", n, "is:", sum_even)
# Out:
# Enter a positive integer: 22
# Sum of all even numbers between 1 and 22 is: 132
