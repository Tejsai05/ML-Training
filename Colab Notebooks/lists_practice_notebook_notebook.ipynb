# %%
#lists are mutable
nums=[1,2,3]
nums
# Out:
# [1, 2, 3]

# %%
diff=[1,2.5,'tejsai']
diff
# Out:
# [1, 2.5, 'tejsai']

# %%
diff[0]
# Out:
# 1

# %%
#methods
diff.append(4)
diff
# Out:
# [1, 2.5, 'tejsai', 4]

# %%
a=nums.sort()
a

# %%
diff.pop()
# Out:
# 4

# %%
diff.insert(2,87)#index value and the inserting value
diff.count(77)
# Out:
# 1

# %%
diff.reverse()
diff
# Out:
# ['tejsai', 77, 77, 87, 2.5, 1]

# %%
nums.remove(1)
nums
# Out:
# [2, 3]

# %%
nums.clear()
nums
# Out:
# []

# %%
diff.pop(3)#3 is index value,87 is removed
diff
# Out:
# ['tejsai', 77, 77, 2.5, 1]

# %%
diff.pop()#if not mentioned index value it chooses last value to remove
# Out:
# 1

# %%
diff
# Out:
# ['tejsai', 77, 77, 2.5]

# %%
del diff[3:]#it delets the all values except 0,1,2 indexes

# %%
diff
# Out:
# ['tejsai', 77, 77]

# %%
diff.count(77)
diff
# Out:
# [4, 5, 6, 7, 23, 77]

# %%
diff.pop(0)
# Out:
# 'tejsai'

# %%
diff
# Out:
# [77]

# %%
diff.extend([23,4,5,6,7])

# %%
diff
# Out:
# [77, 23, 4, 5, 6, 7]

# %%
min(diff)
# Out:
# 4

# %%
max(diff)
# Out:
# 77

# %%
sum(diff)
# Out:
# 122

# %%
diff.sort()
diff
# Out:
# [4, 5, 6, 7, 23, 77]

# %%
diff.extend([77,7,77,77,7])

# %%
diff.count(77)
# Out:
# 4
