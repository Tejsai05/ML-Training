# %%
#encoding is used to convert string or some other values in to numerical values

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
colors = {'color':['Red', 'Blue', 'Green', 'Green', 'Red']}
df=pd.dataframe(colors)
label_encoder = LabelEncoder()
encoded_colors = label_encoder.fit_transform(colors)

print(encoded_colors)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-89a46e2b2a22> in <cell line: 0>()
#       1 colors = {'color':['Red', 'Blue', 'Green', 'Green', 'Red']}
# ----> 2 df=pd.dataframe(colors)
#       3 label_encoder = LabelEncoder()
#       4 encoded_colors = label_encoder.fit_transform(colors)
#       5
#
# AttributeError: module 'pandas' has no attribute 'dataframe'
