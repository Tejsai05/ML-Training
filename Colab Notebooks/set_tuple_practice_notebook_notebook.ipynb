# %%
#tuples are immutable and supports multiple datatypes
#faster than lists
tup=(1,5.5,1,'tejsai')
tup
# Out:
# (1, 5.5, 1, 'tejsai')

# %%
tup.count(1)
# Out:
# 2

# %%
tup.index(1)
# Out:
# 0

# %%
hash_value = hash("Hello, world!")
print(hash_value)  # Produces an integer hash value
# Out:
# 7337788356766820652

# %%
#set are mutable and supports multiple datatypes
#duplications are removed
#has no proper sequence beacuse it follows hashing technique for perfomance optimization
set={1,5.5,1,'tejsai'}
set
# Out:
# {1, 5.5, 'tejsai'}

# %%
set
# Out:
# {1, 5.5, 'tejsai'}

# %%
s={{1,2,3,5,7,8,3,2},{9}}
s
# Out:
# {1, 2, 3, 5, 7, 8}

# %%
s.union({1,2,3,5,7,8,3,2},{9})
# Out:
# {1, 2, 3, 5, 7, 8, 9}

# %%
s.intersection({1,2,3,5,7,8,3,2},{9})
s
# Out:
# {1, 2, 3, 5, 7, 8}

# %%
s.
