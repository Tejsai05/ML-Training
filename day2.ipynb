# %%
my_list = [10, 20, 30, 40, 50]
my_tuple = (1, 2, 3, 4, 5)
my_dict = {'a': 'apple', 'b': 'banana', 'c': 'cherry', 'd': 'date', 'e': 'blueberry'}

list_access = my_list[1:4]
tuple_access = my_tuple[0:3]
dict_access = my_dict['c'], my_dict.get('e')

print(list_access)
print(tuple_access)
print(dict_access)
# Out:
# [20, 30, 40]
# (1, 2, 3)
# ('cherry', 'blueberry')
