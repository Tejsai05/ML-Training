# %%
average=float(input())
if average>=90:
    print("grade A")
elif average==80 and  average==89:
    print("grade B")
elif average==70 and average==79:
    print("grade c")
else:
    print("grade:fail")
# Out:
#  97.5
# grade A
