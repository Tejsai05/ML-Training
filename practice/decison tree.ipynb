# %%
# !pip install  streamlit
# Out:
# /Users/tejsai/.zshenv:export:1: not valid in this context: hello.java
# ...

# %%
##load data
data=pd.read_csv('Heart_Disease_Dataset.csv')
data.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0          Yes  14.96     Yes             Yes     No               7
# 1          Yes  36.93     Yes             Yes     No               3
# 2           No  18.70     Yes              No    Yes              26
# 3          Yes  31.43     Yes             Yes    Yes              24
# 4          Yes  75.64      No              No    Yes               2
#
#    MentalHealth DiffWalking     Sex AgeCategory  \
# 0             6         Yes  Female       25-29
# 1            10          No  Female       30-34
# 2            15          No    Male       70-74
# 3            20          No  Female       40-44
# 4            29          No    Male       35-39
#
#                              Race                 Diabetic PhysicalActivity  \
# 0                           White                      Yes              Yes
# 1                        Hispanic  No, borderline diabetes              Yes
# ...

# %%
data.tail()
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 100196           No  48.02      No              No    Yes              13
# 100197          Yes  82.88      No              No     No              29
# 100198           No  39.46      No             Yes    Yes              23
# 100199           No  46.25     Yes             Yes    Yes               9
# 100200           No  39.26     Yes              No     No              10
#
#         MentalHealth DiffWalking     Sex  AgeCategory  \
# 100196            17          No  Female        45-49
# 100197            23          No    Male        75-79
# 100198             6         Yes    Male  80 or older
# 100199            14          No    Male        25-29
# 100200             5         Yes  Female        25-29
#
#                                   Race                 Diabetic  \
# 100196                           White  No, borderline diabetes
# ...

# %%
#information about columns
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100201 entries, 0 to 100200
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      100201 non-null  object
#  1   BMI               100201 non-null  float64
#  2   Smoking           100201 non-null  object
#  3   AlcoholDrinking   100201 non-null  object
#  4   Stroke            100201 non-null  object
#  5   PhysicalHealth    100201 non-null  int64
#  6   MentalHealth      100201 non-null  int64
#  7   DiffWalking       100201 non-null  object
#  8   Sex               100201 non-null  object
#  9   AgeCategory       100201 non-null  object
#  10  Race              100201 non-null  object
#  11  Diabetic          100201 non-null  object
#  12  PhysicalActivity  100201 non-null  object
#  13  GenHealth         100201 non-null  object
#  14  SleepTime         100201 non-null  float64
#  15  Asthma            100201 non-null  object
# ...

# %%
data.shape
# Out:
# (100201, 18)

# %%
#statstical analysis
data.describe()
# Out:
#                  BMI  PhysicalHealth   MentalHealth      SleepTime
# count  100201.000000   100201.000000  100201.000000  100201.000000
# mean       53.373302       14.503937      14.498239      12.490389
# std        23.878712        8.640423       8.658639       6.632122
# min        12.020000        0.000000       0.000000       1.000000
# 25%        32.760000        7.000000       7.000000       6.700000
# 50%        53.380000       14.000000      15.000000      12.500000
# 75%        73.950000       22.000000      22.000000      18.200000
# max        94.850000       29.000000      29.000000      24.000000

# %%
#checking null values
data.isnull().sum()
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# MentalHealth        0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Race                0
# Diabetic            0
# PhysicalActivity    0
# GenHealth           0
# SleepTime           0
# Asthma              0
# KidneyDisease       0
# SkinCancer          0
# dtype: int64

# %%
#duplicates
data.duplicated().sum()
# Out:
# 0

# %%
data.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 100196    False
# 100197    False
# 100198    False
# 100199    False
# 100200    False
# Length: 100201, dtype: bool

# %%
data.columns
# Out:
# Index(['HeartDisease', 'BMI', 'Smoking', 'AlcoholDrinking', 'Stroke',
#        'PhysicalHealth', 'MentalHealth', 'DiffWalking', 'Sex', 'AgeCategory',
#        'Race', 'Diabetic', 'PhysicalActivity', 'GenHealth', 'SleepTime',
#        'Asthma', 'KidneyDisease', 'SkinCancer'],
#       dtype='object')

# %%
for column in data.columns:
  print(f'{column}:{data[column].unique()}')
# Out:
# HeartDisease:['Yes' 'No']
# BMI:[14.96 36.93 18.7  ... 15.41 91.36 36.29]
# Smoking:['Yes' 'No']
# AlcoholDrinking:['Yes' 'No']
# Stroke:['No' 'Yes']
# PhysicalHealth:[ 7  3 26 24  2 12  5  6 19 11  8 16 20  4 15  1  9 14 27  0 17 28 29 23
#  18 10 25 21 22 13]
# MentalHealth:[ 6 10 15 20 29 27 13  7  2 25 11 26 12 28 14 22 16  5  1  0 24  9 21 23
#   8  4  3 17 18 19]
# DiffWalking:['Yes' 'No']
# Sex:['Female' 'Male']
# AgeCategory:['25-29' '30-34' '70-74' '40-44' '35-39' '50-54' '75-79' '60-64' '18-24'
#  '55-59' '65-69' '45-49' '80 or older']
# Race:['White' 'Hispanic' 'American Indian/Alaskan Native' 'Black' 'Asian'
#  'Other']
# Diabetic:['Yes' 'No, borderline diabetes' 'No' 'Yes (during pregnancy)']
# PhysicalActivity:['Yes' 'No']
# GenHealth:['Fair' 'Poor' 'Excellent' 'Good' 'Very good']
# SleepTime:[17.1  2.7 15.6  1.4  8.8  4.8 12.  22.4 16.3 20.9  3.5 19.1 15.9 10.4
#  18.9 19.  17.4  7.1  1.  20.6 21.6 11.4 10.5  5.6  4.5 22.7 20.8  7.
# ...

# %%
for column in data.columns:
  print(data[column].value_counts())
# Out:
# HeartDisease
# Yes    50134
# No     50067
# Name: count, dtype: int64
# BMI
# 56.38    26
# 91.47    26
# 27.95    26
# 88.49    26
# 66.39    25
#          ..
# 23.75     3
# 29.15     3
# 65.14     3
# 34.33     2
# 91.36     2
# Name: count, Length: 8284, dtype: int64
# Smoking
# Yes    50445
# No     49756
# Name: count, dtype: int64
# AlcoholDrinking
# Yes    50435
# No     49766
# Name: count, dtype: int64
# Stroke
# Yes    50265
# No     49936
# Name: count, dtype: int64
# PhysicalHealth
# 8     3430
# 20    3401
# 9     3395
# 16    3392
# 19    3386
# 13    3385
# 12    3377
# 26    3369
# 29    3363
# 15    3355
# 23    3354
# 22    3347
# 28    3345
# 14    3343
# 2     3341
# 1     3337
# 10    3334
# 11    3332
# 6     3329
# 0     3328
# 17    3327
# 7     3323
# 24    3316
# 5     3305
# 18    3301
# 3     3287
# 21    3285
# 27    3277
# 25    3270
# 4     3267
# Name: count, dtype: int64
# MentalHealth
# 27    3442
# 16    3442
# 13    3419
# 5     3403
# ...

# %%
#one hot encoding
data=pd.get_dummies(data,columns=['Diabetic'],drop_first=True)
data.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0          Yes  14.96     Yes             Yes     No               7
# 1          Yes  36.93     Yes             Yes     No               3
# 2           No  18.70     Yes              No    Yes              26
# 3          Yes  31.43     Yes             Yes    Yes              24
# 4          Yes  75.64      No              No    Yes               2
#
#    MentalHealth DiffWalking     Sex AgeCategory  \
# 0             6         Yes  Female       25-29
# 1            10          No  Female       30-34
# 2            15          No    Male       70-74
# 3            20          No  Female       40-44
# 4            29          No    Male       35-39
#
#                              Race PhysicalActivity  GenHealth  SleepTime  \
# 0                           White              Yes       Fair       17.1
# 1                        Hispanic              Yes       Poor        2.7
# ...

# %%
#convert binary categorical variables into numerical columns
binary_cols=['Sex','Smoking','AlcoholDrinking','PhysicalActivity','Asthma','KidneyDisease','SkinCancer']
for col in binary_cols:
  data[col]=data[col].map({'Yes':1,'No':0})

# %%
binary_cols
# Out:
# ['Sex',
#  'Smoking',
#  'AlcoholDrinking',
#  'PhysicalActivity',
#  'Asthma',
#  'KidneyDisease',
#  'SkinCancer']
